# %%
import pandas as pd

product_df = pd.read_csv("./wconcept_data/wconcept_products_20260913_234742.csv")
review_df = pd.read_csv("./wconcept_data/wconcept_reviews_20260913_234742.csv")
blog_df = pd.read_csv("./wconcept_data/wconcept_blogs_20260914_001928.csv")

# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/17.7 MB ? eta -:--:--
#    ---------------------------------------  17.6/17.7 MB 102.1 MB/s eta 0:00:01
#    ---------------------------------------- 17.7/17.7 MB 87.6 MB/s  0:00:00
# ...

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="0000",
    database="wconcept_db_260915"
)

cursor = conn.cursor()

# %%
#파이썬 수집 데이터결측치의 값: null -> NaN, NaT -> mysql: None
 
def to_none(value) :
    if pd.isna(value) :
        return None
    return value

# %%
from datetime import datetime

collected_at = datetime.now()

sql = """
INSERT INTO crawl_runs (collected_at) VALUES (%s)
"""

cursor.execute(sql, (collected_at, )) # 튜플로 인식시키기 위해 ,위에 공백 사용 괜춘

crawl_run_id = cursor.lastrowid

print("crawl_run_id: ", crawl_run_id)
# Out:
# crawl_run_id:  1
